# %%
# !pip install plotly==4.8
# Out:
# Collecting plotly==4.8
#   Downloading https://files.pythonhosted.org/packages/4e/ea/da824c4b016629ea21c667bcc7999359d08e4bc5a06aeee31c61a3785573/plotly-4.8.0-py2.py3-none-any.whl (11.5MB)
#      |████████████████████████████████| 11.5MB 7.9MB/s
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly==4.8) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly==4.8) (1.15.0)
# Installing collected packages: plotly
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# Successfully installed plotly-4.8.0

# %% [markdown]
# # **Churn Modeling Using Logit**
# [Data - Churn Modeling from Kaggle](https://www.kaggle.com/c/churn-modelling/data)

# %%
#Imports

import pandas as pd
import plotly.express as px
from statsmodels.formula.api import logit
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from sklearn.preprocessing import quantile_transform
import numpy as np
import seaborn as sns

import ipywidgets as widgets

import plotly.graph_objects as go
from plotly.subplots import make_subplots
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Reading the data
df = pd.read_csv("Churn_Modelling.csv",index_col=["RowNumber","CustomerId","Surname"])
df.head()
# Out:
#                                CreditScore Geography  ... EstimatedSalary  Exited
# RowNumber CustomerId Surname                          ...
# 1         15634602   Hargrave          619    France  ...       101348.88       1
# 2         15647311   Hill              608     Spain  ...       112542.58       0
# 3         15619304   Onio              502    France  ...       113931.57       1
# 4         15701354   Boni              699    France  ...        93826.63       0
# 5         15737888   Mitchell          850     Spain  ...        79084.10       0
#
# [5 rows x 11 columns]

# %%
categorical_cols = ["Geography", "Gender", "Tenure", "NumOfProducts", "HasCrCard",]
non_categorical_cols = ["CreditScore", "Age", "Balance", "EstimatedSalary"]

# %% [markdown]
# ## Data Exploration - Continious Features

# %%
# -----Create a Dropdown for selecting Regressor(Continious) for analysis--------

w = widgets.Dropdown(
    options=non_categorical_cols,
    value="CreditScore",
    description="Task:",
)
display(w)
# Out:
# Dropdown(description='Task:', options=('CreditScore', 'Age', 'Balance', 'EstimatedSalary'), value='CreditScore…

# %%
non_categorical_col = w.value

layout = go.Layout(plot_bgcolor='#F0E9E6')

fig = go.Figure(layout=layout)
fig.add_trace(go.Box(y=df.loc[df["Exited"]==1,non_categorical_col],\
                     marker_color = 'indianred',
                     name="Churn"))
fig.add_trace(go.Box(y=df.loc[df["Exited"]==0,non_categorical_col],\
                     marker_color = 'lightseagreen',
                     name="Non Churn"))

fig.update_layout(
                   title='Continious Regressor to Target',
                   xaxis_title=f"{non_categorical_col}",
                   yaxis_title='IQR', 
                   xaxis_showgrid=False, 
                   yaxis_showgrid=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d171e9c1-10ba-4812-b905-fe25d44de3c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d171e9c1-10ba-4812-b905-fe25d44de3c5")) {
#                     Plotly.newPlot(
#                         'd171e9c1-10ba-4812-b905-fe25d44de3c5',
#                         [{"marker": {"color": "indianred"}, "name": "Churn", "type": "box", "y": [42, 42, 44, 29, 58, 38, 39, 45, 51, 49, 27, 39, 41, 42, 66, 58, 32, 22, 46, 44, 65, 46, 35, 28, 31, 42, 52, 56, 48, 35, 52, 31, 48, 57, 29, 24, 39, 44, 55, 50, 41, 50, 38, 41, 45, 47, 43, 54, 33, 45, 39, 50, 42, 43,
# 0  Female      3404   1139
# 1    Male      4559    898

# %%
categorical_col = w_cat.value

target_classes = [ "No Churn", "Churn"]

#layout = go.Layout(plot_bgcolor='#F0E9E6')

fig = px.bar(ct, x=categorical_col, y=ct.columns[1:].tolist(),\
             color_discrete_sequence=['indianred','lightseagreen'] )

fig.update_layout(
                   plot_bgcolor='#F0E9E6',
                   title='Categorical Regressor to Target',
                   xaxis_title=f"{categorical_col}",
                   yaxis_title='Count', 
                   xaxis_showgrid=False, 
                   yaxis_showgrid=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6113f9a5-56f4-424c-a276-be6e3645359b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6113f9a5-56f4-424c-a276-be6e3645359b")) {
#                     Plotly.newPlot(
#                         '6113f9a5-56f4-424c-a276-be6e3645359b',
#                         [{"alignmentgroup": "True", "hovertemplate": "variable=No Churn<br>Gender=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "No Churn", "marker": {"color": "indianred"}, "name": "No Churn", "offsetgroup": "No Churn", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Female", "Male"], "xaxis": "x", "y": [3404, 4559], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=Churn<br>Gender=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Churn", "marker": {"color": "lightseagreen"}, "name": "Churn", "offsetgroup": "Churn", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Female", "Male"], "xaxis": "x", "y": [1139, 898], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "plot_bgcolor": "#F0E9E6", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": ...

# %% [markdown]
# ## Fitting a Logit

# %%
categorical_cols = ["Geography", "Gender",  "HasCrCard",]
non_categorical_cols = ["Age"]

formula = "Exited"+"~"+"+".join(non_categorical_cols)+"+"+\
          "+".join([f"C({each_categorcial_col})" for each_categorcial_col\
                    in categorical_cols]) + "-" + "1"
formula
# Out:
# 'Exited~Age+C(Geography)+C(Gender)+C(HasCrCard)-1'

# %%
logitfit = logit(formula = str(formula), 
                 data = df).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.449401
#          Iterations 6

# %% [markdown]
# ## Goodness Of Fit

# %%
df["proba"] = logitfit.predict(df)
df["predicted"] = 0

#A treshold of 0.3 helps in taking care of the imbalnce
df.loc[df["proba"]>0.3,"predicted"] = 1

# %%
ct = pd.crosstab(df["predicted"], df["Exited"])
ct.columns = ["No Churn","Churn"]
ct.index = ["No Churn(Predicted)","Churn(Predicted)"]
ct =ct.reset_index()
ct
# Out:
#                  index  No Churn  Churn
# 0  No Churn(Predicted)      6883   1154
# 1     Churn(Predicted)      1080    883

# %%
labels=['actuals','predicted']

actual_churn = df.loc[df["Exited"]==1,:].shape[0]
actual_no_churn = df.loc[df["Exited"]==0,:].shape[0]
predicted_churn = df.loc[df["predicted"]==1,:].shape[0]
predicted_no_churn = df.loc[df["predicted"]==0,:].shape[0]

# %%
labels=['actuals','predicted']

actual_churn = df.loc[df["Exited"]==1,:].shape[0]
actual_no_churn = df.loc[df["Exited"]==0,:].shape[0]
predicted_churn = df.loc[df["predicted"]==1,:].shape[0]
predicted_no_churn = df.loc[df["predicted"]==0,:].shape[0]

fig = go.Figure(data=[
    go.Bar(name='Churn', x=labels, y=[actual_churn, predicted_churn],\
           ),
    go.Bar(name='No Churn', x=labels, y=[actual_no_churn, predicted_no_churn],\
           )
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="166c5698-5f8c-4794-ac7d-64f5777ab3d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("166c5698-5f8c-4794-ac7d-64f5777ab3d3")) {
#                     Plotly.newPlot(
#                         '166c5698-5f8c-4794-ac7d-64f5777ab3d3',
#                         [{"name": "Churn", "type": "bar", "x": ["actuals", "predicted"], "y": [2037, 1963]}, {"name": "No Churn", "type": "bar", "x": ["actuals", "predicted"], "y": [7963, 8037]}],
#                         {"barmode": "stack", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"mark ...

# %% [markdown]
# ## Extracting the model Coefficients

# %%
#Extracting Logit's coefficients and sorting them.
logit_coeffs = logitfit.summary2().tables[1]
logit_coeffs = logit_coeffs.reindex(logit_coeffs["Coef."].abs().sort_values().index)

# %%
logit_coeffs.head(10)
# Out:
#                           Coef.  Std.Err.  ...    [0.025    0.975]
# C(HasCrCard)[T.1]     -0.031968  0.057911  ... -0.145472  0.081536
# Age                    0.063294  0.002415  ...  0.058561  0.068028
# C(Gender)[T.Male]     -0.529893  0.053130  ... -0.634025 -0.425761
# C(Geography)[Germany] -3.021432  0.119103  ... -3.254870 -2.787995
# C(Geography)[Spain]   -3.913336  0.126652  ... -4.161569 -3.665103
# C(Geography)[France]  -3.935134  0.119654  ... -4.169651 -3.700617
#
# [6 rows x 6 columns]

# %% [markdown]
# ### Global Feature Importance

# %%
fig = px.bar(ct, x=logit_coeffs['Coef.'],\
             y=logit_coeffs['Coef.'].index,
             orientation="h",
             color_discrete_sequence=['lightseagreen'] )

fig.update_layout(
                   plot_bgcolor='#F0E9E6',
                   title='Feature Importances',
                   xaxis_title='Coefficient Importance',
                   yaxis_title='Features', 
                   xaxis_showgrid=False, 
                   yaxis_showgrid=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f6e65f35-3310-49ba-8d32-01296e389159" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f6e65f35-3310-49ba-8d32-01296e389159")) {
#                     Plotly.newPlot(
#                         'f6e65f35-3310-49ba-8d32-01296e389159',
#                         [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "lightseagreen"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [-0.03196811861893409, 0.0632944130597942, -0.5298928321842181, -3.021432476643898, -3.9133359804710834, -3.935134250078374], "xaxis": "x", "y": ["C(HasCrCard)[T.1]", "Age", "C(Gender)[T.Male]", "C(Geography)[Germany]", "C(Geography)[Spain]", "C(Geography)[France]"], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "plot_bgcolor": "#F0E9E6", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"out ...

# %% [markdown]
# ### Global Feature Importance for Significance

# %%
layout = go.Layout(plot_bgcolor='#F0E9E6')
fig = go.Figure(layout=layout)

fig.add_trace(
    go.Scatter(
    x=logit_coeffs['Coef.'],
    y=logit_coeffs['Coef.'].index,
    line=dict(color='#42C4F7', width=2),
    mode='markers',
        
    error_x=dict(
            type='data',
            symmetric=False,
            array=logit_coeffs['0.975]'] - logit_coeffs['Coef.'],
            arrayminus=logit_coeffs['Coef.'] - logit_coeffs['[0.025'],
            color='#8793c4')
        )
    )


fig.update_layout(
                   title='Regression Meta Analysis',
                   xaxis_title='Weight Estimates',
                   yaxis_title='Variable', 
                   xaxis_showgrid=False, 
                   yaxis_showgrid=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="06407a35-0715-470d-8b0f-f3187c4ec621" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("06407a35-0715-470d-8b0f-f3187c4ec621")) {
#                     Plotly.newPlot(
#                         '06407a35-0715-470d-8b0f-f3187c4ec621',
#                         [{"error_x": {"array": [0.11350377894626482, 0.004733619140044221, 0.10413217182510848, 0.23343756180695907, 0.24823333228353617, 0.2345169166566876], "arrayminus": [0.11350377894626482, 0.004733619140044221, 0.10413217182510848, 0.23343756180695907, 0.24823333228353617, 0.23451691665668806], "color": "#8793c4", "symmetric": false, "type": "data"}, "line": {"color": "#42C4F7", "width": 2}, "mode": "markers", "type": "scatter", "x": [-0.03196811861893409, 0.0632944130597942, -0.5298928321842181, -3.021432476643898, -3.9133359804710834, -3.935134250078374], "y": ["C(HasCrCard)[T.1]", "Age", "C(Gender)[T.Male]", "C(Geography)[Germany]", "C(Geography)[Spain]", "C(Geography)[France]"]}],
#                         {"plot_bgcolor": "#F0E9E6", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary":  ...

# %%
logit_coeffs['Coef.']
# Out:
# C(HasCrCard)[T.1]       -0.031968
# Age                      0.063294
# C(Gender)[T.Male]       -0.529893
# C(Geography)[Germany]   -3.021432
# C(Geography)[Spain]     -3.913336
# C(Geography)[France]    -3.935134
# Name: Coef., dtype: float64

# %% [markdown]
# Dummy Encode the Data to multiply coefficients

# %%
dummy_encoded_df = pd.get_dummies(df[non_categorical_cols+categorical_cols],\
               columns=["Geography"])

dummy_encoded_df = dummy_encoded_df[["HasCrCard", "Age", "Gender",
                                      "Geography_Germany", "Geography_Spain",	\
                                      "Geography_France",
                                      ]]
dummy_encoded_df["Gender"] = dummy_encoded_df["Gender"].map({
    "Female":0, "Male":1
}) 
dummy_encoded_df.head()
# Out:
#                                HasCrCard  ...  Geography_France
# RowNumber CustomerId Surname              ...
# 1         15634602   Hargrave          1  ...                 1
# 2         15647311   Hill              0  ...                 0
# 3         15619304   Onio              1  ...                 1
# 4         15701354   Boni              0  ...                 1
# 5         15737888   Mitchell          1  ...                 0
#
# [5 rows x 6 columns]

# %%
#Compute effects
effects = dummy_encoded_df * logit_coeffs['Coef.'].to_numpy()
effects.head()
# Out:
#                                HasCrCard  ...  Geography_France
# RowNumber CustomerId Surname              ...
# 1         15634602   Hargrave  -0.031968  ...         -3.935134
# 2         15647311   Hill      -0.000000  ...         -0.000000
# 3         15619304   Onio      -0.031968  ...         -3.935134
# 4         15701354   Boni      -0.000000  ...         -3.935134
# 5         15737888   Mitchell  -0.031968  ...         -0.000000
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Effects Plot

# %%
layout = go.Layout(plot_bgcolor='#F0E9E6')

fig = go.Figure(layout=layout)

for each_col in effects.columns:
    fig.add_trace(go.Box(x=effects[each_col],\
                     marker_color = 'lightseagreen',
                     name=each_col))

fig.update_layout(
                   title='Effect Plot',
                   xaxis_title="Effects",
                   yaxis_title='Features', 
                   xaxis_showgrid=False, 
                   yaxis_showgrid=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4fd92d8f-aa67-4a34-bf5c-19e30da28bf2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4fd92d8f-aa67-4a34-bf5c-19e30da28bf2")) {
#                     Plotly.newPlot(
#                         '4fd92d8f-aa67-4a34-bf5c-19e30da28bf2',
#                         [{"marker": {"color": "lightseagreen"}, "name": "HasCrCard", "type": "box", "x": [-0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.031968118 ...

# %%
(df["proba"]>0.5).head(30)
# Out:
# RowNumber  CustomerId  Surname
# 1          15634602    Hargrave      False
# 2          15647311    Hill          False
# 3          15619304    Onio          False
# 4          15701354    Boni          False
# 5          15737888    Mitchell      False
# 6          15574012    Chu           False
# 7          15592531    Bartlett      False
# 8          15656148    Obinna        False
# 9          15792365    He            False
# 10         15592389    H?            False
# 11         15767821    Bearce        False
# 12         15737173    Andrews       False
# 13         15632264    Kay           False
# 14         15691483    Chin          False
# 15         15600882    Scott         False
# 16         15643966    Goforth       False
# 17         15737452    Romeo          True
# 18         15788218    Henderson     False
# 19         15661507    Muldrow       False
# 20         15568982    Hao           False
# 21         15577657    McDonald      False
# 22         15597945    Dellucci      False
# 23         15699309    Gerasimov     False
# 24         15725737    Mosman        False
# 25         15625047    Yen           False
# 26         15738191    Maclean       False
# 27         15736816    Young         False
# 28         15700772    Nebechi       False
# 29         15728693    McWilliams    False
# 30         15656300    Lucciano      False
# Name: proba, dtype: bool

# %% [markdown]
# ### Local Interpretability

# %%
SET_INDEX_DF = 16

local_data = dummy_encoded_df.iloc[SET_INDEX_DF,:]
local_effects =  effects.iloc[SET_INDEX_DF,:]
local_data,local_effects
# Out:
# (HasCrCard             1
#  Age                  58
#  Gender                1
#  Geography_Germany     1
#  Geography_Spain       0
#  Geography_France      0
#  Name: (17, 15737452, Romeo), dtype: int64, HasCrCard           -0.031968
#  Age                  3.671076
#  Gender              -0.529893
#  Geography_Germany   -3.021432
#  Geography_Spain     -0.000000
#  Geography_France    -0.000000
#  Name: (17, 15737452, Romeo), dtype: float64)

# %%
dummy_encoded_df.iloc[SET_INDEX_DF:SET_INDEX_DF+1,:].head()
# Out:
#                               HasCrCard  Age  ...  Geography_Spain  Geography_France
# RowNumber CustomerId Surname                  ...
# 17        15737452   Romeo            1   58  ...                0                 0
#
# [1 rows x 6 columns]

# %%
layout = go.Layout(plot_bgcolor='#F0E9E6')

fig = go.Figure(layout=layout)

for each_col in effects.columns:
    fig.add_trace(go.Box(x=effects[each_col],\
                     marker_color = 'lightseagreen',
                     name=each_col))


fig.add_trace(go.Scatter(
    x=local_effects.to_numpy(),
    y=local_effects.index,
    hovertext=local_data.to_numpy(),
    hoverinfo="text",
    marker=dict(
        color="red"
    ),
    mode="markers",
    marker_symbol="square-x",
    showlegend=False
))



fig.update_layout(
                   title=f'Local Effects of Data Point {SET_INDEX_DF},Predicted Log Odds-{df.iloc[SET_INDEX_DF,:]["proba"]}',
                   xaxis_title="Effects",
                   yaxis_title='Features', 
                   xaxis_showgrid=False, 
                   yaxis_showgrid=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="44961231-cdb2-44fd-a3ff-04ddc5cd8325" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("44961231-cdb2-44fd-a3ff-04ddc5cd8325")) {
#                     Plotly.newPlot(
#                         '44961231-cdb2-44fd-a3ff-04ddc5cd8325',
#                         [{"marker": {"color": "lightseagreen"}, "name": "HasCrCard", "type": "box", "x": [-0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.0, -0.0, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.03196811861893409, -0.0, -0.031968118 ...
